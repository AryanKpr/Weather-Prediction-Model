# %%
import pandas as pd

weather=pd.read_csv('/Users/ADMIN/Desktop/weather.csv',index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2025-07-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.84
# 2025-07-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.32
# 2025-07-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.41
# 2025-07-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.96
# 2025-07-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %%
weather.isnull().any()
null=weather.isnull().sum()
pct=null/weather.shape[0]

# %%
pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.525864
# ACSH       0.525815
# AWND       0.254007
# FMTM       0.500764
# PGTM       0.391686
# PRCP       0.001479
# SNOW       0.001479
# SNWD       0.001529
# TAVG       0.647123
# TMAX       0.001479
# TMIN       0.001479
# TSUN       0.998471
# WDF1       0.526061
# WDF2       0.476010
# WDF5       0.480103
# WDFG       0.747473
# WDFM       0.999951
# WESD       0.700626
# WSF1       0.525914
# WSF2       0.476010
# WSF5       0.480152
# WSFG       0.631984
# WSFM       0.999951
# WT01       0.631737
# WT02       0.934514
# WT03       0.933231
# WT04       0.982691
# WT05       0.982050
# WT06       0.990976
# WT07       0.994674
# WT08       0.804132
# WT09       0.993096
# WT11       0.999310
# WT13       0.892253
# WT14       0.956260
# WT15       0.997929
# WT16       0.675674
# WT17       0.997041
# WT18       0.942453
# WT19       0.999951
# WT21       0.999753
# WT22       0.997584
# WV01       0.999951
# ...

# %%
valid=weather.columns[pct<0.05]

# %%
valid
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[valid].copy()

# %%
weather.columns=weather.columns.str.lower()
print(weather)
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-07-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 2025-07-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
# 2025-07-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN   NaN   NaN
#
#             tmax  tmin
# DATE
# ...

# %%
weather=weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025    190
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-07-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 2025-07-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
# 2025-07-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather["target"]=weather.shift(-1)["tmax"]
weather.ffill()
print(weather)
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-07-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 2025-07-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
# 2025-07-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
weather=weather.ffill()
print(weather)
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-07-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-07-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 2025-07-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
# 2025-07-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=0.1)

# %%
predictors=[]
for i in weather.columns:
    if i not in ["target", "name", "station"]:
        predictors.append(i)
print(predictors)
# Out:
# ['prcp', 'snow', 'snwd', 'tmax', 'tmin']

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictors=[]

    for i in range(start, weather.shape[0], step):
        train=weather.iloc[:i,:]
        test=weather.iloc[i:(i+step),:]

        model.fit(train[predictors], train["target"])
        preds=model.predict(test[predictors])

        preds=pd.Series(preds,index=test.index)
        combined=pd.concat([test["target"],preds],axis=1)

        combined.columns=["actual","prediction"]
        combined["diff"]=(combined["prediction"]-combined["actual"]).abs()

        all_predictors.append(combined)
    return pd.concat(all_predictors)

# %%
predictions=backtest(weather,ridge,predictors)
print(predictions)
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2025-07-05    86.0   82.890932   3.109068
# 2025-07-06    87.0   84.941937   2.058063
# 2025-07-07    93.0   87.432414   5.567586
# 2025-07-08    93.0   89.838696   3.161304
# 2025-07-09    93.0   89.838696   3.161304
#
# [16629 rows x 3 columns]
